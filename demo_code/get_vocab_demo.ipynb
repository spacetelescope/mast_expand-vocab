# %%
import rdflib

import csv # csv is only needed for this demo, writing to a csv file instead of a database

# %%
# Just setting up csv file writing
output_path = 'test_output.csv'

# Set up output columns
output_columns = ['tag_uri', 'tag_uri_short', 'tag_prefLabel',
                  'vocab','vocab_level', 'caomMatch_uri',
                  'ivoaMatch_uri', 'uatMatch_uri']

# %%
# Read in the vocabulary

vocab_url = "https://raw.githubusercontent.com/spacetelescope/mast_expand-vocab/main/vocabs/data-product-type.rdf"

g = rdflib.Graph().parse(vocab_url,format='xml') # Read the vocabulary into an rdflib graph.

# %%
# Set vocab and vocab_level. 
# I will work on a better way to do this.

if 'data-product-type.rdf' in vocab_url:
    vocab = 'DataProductType'
    vocab_level = 'product'
elif 'basis.rdf' in vocab_url:
    vocab = 'Basis'
    vocab_level = 'product'
else:
    print('Vocabulary not recognized.')

# %%
# The "with open" is just for csv file writing.
with open(output_path, 'w', newline='') as output_file:
    csv_writer = csv.DictWriter(output_file, fieldnames = output_columns) # more csv stuff
    csv_writer.writeheader() # more csv stuff
    
    # loop through all triples of type skos:Concept. None is a wildcard.
    for tag_uri, _, _ in g.triples((None, rdflib.RDF.type, rdflib.SKOS.Concept)):
        
        # We already have tag_uri from the for loop setup.
        # Let's get a couple more values:
        tag_prefLabel = g.value(tag_uri, rdflib.SKOS.prefLabel, None) # prefLabel
        tag_uri_short = tag_uri.split('#', 1)[1] # tag_uri_short is the everything after the hashtag
        
        
        # For this concept, get the match URIs for external vocabs.
        match_uris = g.objects(tag_uri,
                               rdflib.SKOS.exactMatch |
                               rdflib.SKOS.broadMatch,
                               None)
    
        # Set default match URI values.
        # Probably there is a more elegant way to do this.
        ivoaMatch_uri = None
        uatMatch_uri = None
        caomMatch_uri = None
        
        # Populate match URI values
        for uri in match_uris:
            if 'ivoa.net/rdf/' in uri:
                ivoaMatch_uri = uri
            elif 'astrothesaurus.org/uat/' in uri:
                uatMatch_uri = uri
            elif 'opencadc.org/caom' in uri:
                caomMatch_uri = uri
            else:
                # Error handling.
                pass
        

        # Ultimately, we'll want to assign a tag ID, check if the tag is already in the database, 
        # and edit column values without overwriting the tag ID if anything has changed.
        # But for now:
        csv_writer.writerow({
            "tag_uri": tag_uri,
            "tag_uri_short": tag_uri_short,
            "tag_prefLabel": tag_prefLabel,
            "vocab": vocab,
            "vocab_level": vocab_level,
            "caomMatch_uri": caomMatch_uri,
            "uatMatch_uri": uatMatch_uri,
            "ivoaMatch_uri": ivoaMatch_uri
        })

# %% [markdown]
# Keep in mind that eventually this table will include concepts from multiple vocabularies, in our current draft schema. And we'll also need different behavior if a tag URI is already in the table, manage unique tag IDs, and so on. But for now, let's look at what we made:

# %%
import pandas as pd
display = pd.read_csv(output_path)
display
# Out:
#                                               tag_uri  \
# 0   https://archive.stsci.edu/rdf/data-product-typ...
# 1   https://archive.stsci.edu/rdf/data-product-typ...
# 2   https://archive.stsci.edu/rdf/data-product-typ...
# 3   https://archive.stsci.edu/rdf/data-product-typ...
# 4   https://archive.stsci.edu/rdf/data-product-typ...
# 5   https://archive.stsci.edu/rdf/data-product-typ...
# 6   https://archive.stsci.edu/rdf/data-product-typ...
# 7   https://archive.stsci.edu/rdf/data-product-typ...
# 8   https://archive.stsci.edu/rdf/data-product-typ...
# 9   https://archive.stsci.edu/rdf/data-product-typ...
# 10  https://archive.stsci.edu/rdf/data-product-typ...
# 11  https://archive.stsci.edu/rdf/data-product-typ...
# 12  https://archive.stsci.edu/rdf/data-product-typ...
# 13  https://archive.stsci.edu/rdf/data-product-typ...
# 14  https://archive.stsci.edu/rdf/data-product-typ...
# 15  https://archive.stsci.edu/rdf/data-product-typ...
# 16  https://archive.stsci.edu/rdf/data-product-typ...
# 17  https://archive.stsci.edu/rdf/data-product-typ...
# 18  https://archive.stsci.edu/rdf/data-product-typ...
# 19  https://archive.stsci.edu/rdf/data-product-typ...
# 20  https://archive.stsci.edu/rdf/data-product-typ...
# 21  https://archive.stsci.edu/rdf/data-product-typ...
# 22  https://archive.stsci.edu/rdf/data-product-typ...
# 23  https://archive.stsci.edu/rdf/data-product-typ...
# 24  https://archive.stsci.edu/rdf/data-product-typ...
# 25  https://archive.stsci.edu/rdf/data-product-typ...
# 26  https://archive.stsci.edu/rdf/data-product-typ...
# 27  https://archive.stsci.edu/rdf/data-product-typ...
# 28  https://archive.stsci.edu/rdf/data-product-typ...
# 29  https://archive.stsci.edu/rdf/data-product-typ...
# 30  https://archive.stsci.edu/rdf/data-product-typ...
# 31  https://archive.stsci.edu/rdf/data-product-typ...
# 32  https://archive.stsci.edu/rdf/data-product-typ...
# 33  https://archive.stsci.edu/rdf/data-product-typ...
# 34  https://archive.stsci.edu/rdf/data-product-typ...
# 35  https://archive.stsci.edu/rdf/data-product-typ...
# 36  https://archive.stsci.edu/rdf/data-product-typ...
# 37  https://archive.stsci.edu/rdf/data-product-typ...
# 38  https://archive.stsci.edu/rdf/data-product-typ...
# 39  https://archive.stsci.edu/rdf/data-product-typ...
# 40  https://archive.stsci.edu/rdf/data-product-typ...
# 41  https://archive.stsci.edu/rdf/data-product-typ...
# 42  https://archive.stsci.edu/rdf/data-product-typ...
# 43  https://archive.stsci.edu/rdf/data-product-typ...
# 44  https://archive.stsci.edu/rdf/data-product-typ...
# 45  https://archive.stsci.edu/rdf/data-product-typ...
# 46  https://archive.stsci.edu/rdf/data-product-typ...
# 47  https://archive.stsci.edu/rdf/data-product-typ...
# 48  https://archive.stsci.edu/rdf/data-product-typ...
# 49  https://archive.stsci.edu/rdf/data-product-typ...
# 50  https://archive.stsci.edu/rdf/data-product-typ...
# 51  https://archive.stsci.edu/rdf/data-product-typ...
# 52  https://archive.stsci.edu/rdf/data-product-typ...
# 53  https://archive.stsci.edu/rdf/data-product-typ...
# 54  https://archive.stsci.edu/rdf/data-product-typ...
# 55  https://archive.stsci.edu/rdf/data-product-typ...
# 56  https://archive.stsci.edu/rdf/data-product-typ...
# 57  https://archive.stsci.edu/rdf/data-product-typ...
# 58  https://archive.stsci.edu/rdf/data-product-typ...
# 59  https://archive.stsci.edu/rdf/data-product-typ...
#
#                               tag_uri_short  \
# 0                        Abundance_catalogs
# 1                      Astrometric_catalogs
# 2                                  Catalogs
# 3                 Co-trending_basis_vectors
# 4                                      Code
# 5                      Coronagraphic_images
# 6            Cylindrically_projected_images
# 7                           Dithered_images
# 8                            Doppler_images
# 9                           Drizzled_images
# 10                              Ephemerides
# 11                      Extinction_catalogs
# 12                        Full_Frame_Images
# 13                    HEALPixel_projections
# 14                            Image_mosaics
# 15                             Image_stacks
# 16                                   Images
# 17                   Interferometric_images
# 18  Intrinsic_spectral_energy_distributions
# 19                             Light_curves
# 20                Long-slit_spectral_images
# 21                                    Masks
# 22                            Mass_catalogs
# 23                     Metallicity_catalogs
# 24       Multi-instrument_composite_spectra
# 25           Multi-object_composite_spectra
# 26         Multi-waveband_composite_spectra
# 27                         Navigated_images
# 28                      Photometry_catalogs
# 29                   Point_spread_functions
# 30                        Polarimetric_data
# 31                            Power_spectra
# 32                        Redshift_catalogs
# 33                 Rotation_period_catalogs
# 34                        Segmentation_maps
# 35             Slitless_spectroscopy_images
# 36                          Source_catalogs
# 37           Source_classification_catalogs
# 38                                  Spectra
# 39                  Spectra_of_polarization
# 40                     Spectral_image_cubes
# 41                          Spectral_images
# 42                     Spectral_line_images
# 43               Spectral_line_light_curves
# 44                      Spectral_line_lists
# 45            Spectral_line_source_catalogs
# 46                          Spectrum_stacks
# 47                 Surface_gravity_catalogs
# 48                       Target_Pixel_Files
# 49                     Temperature_catalogs
# 50                  Time-tagged_event_lists
# 51                         Time_domain_data
# 52                              Time_series
# 53                       Time_series_images
# 54                      Time_series_spectra
# 55              Turbulent_velocity_catalogs
# 56                                 Uncommon
# 57                     Velocity-time_curves
# 58                            Velocity_maps
# 59                          Visibility_data
#
#                               tag_prefLabel            vocab vocab_level  \
# 0                        Abundance catalogs  DataProductType     product
# 1                      Astrometric catalogs  DataProductType     product
# 2                                  Catalogs  DataProductType     product
# 3                 Co-trending basis vectors  DataProductType     product
# 4                                      Code  DataProductType     product
# 5                      Coronagraphic images  DataProductType     product
# 6            Cylindrically projected images  DataProductType     product
# 7                           Dithered images  DataProductType     product
# 8                            Doppler images  DataProductType     product
# 9                           Drizzled images  DataProductType     product
# 10                              Ephemerides  DataProductType     product
# 11                      Extinction catalogs  DataProductType     product
# 12                        Full Frame Images  DataProductType     product
# 13                    HEALPixel projections  DataProductType     product
# 14                            Image mosaics  DataProductType     product
# 15                             Image stacks  DataProductType     product
# 16                                   Images  DataProductType     product
# 17                   Interferometric images  DataProductType     product
# 18  Intrinsic spectral energy distributions  DataProductType     product
# 19                             Light curves  DataProductType     product
# 20                Long-slit spectral images  DataProductType     product
# 21                                    Masks  DataProductType     product
# 22                            Mass catalogs  DataProductType     product
# 23                     Metallicity catalogs  DataProductType     product
# 24       Multi-instrument composite spectra  DataProductType     product
# 25           Multi-object composite spectra  DataProductType     product
# 26         Multi-waveband composite spectra  DataProductType     product
# 27                         Navigated images  DataProductType     product
# 28                      Photometry catalogs  DataProductType     product
# 29                   Point spread functions  DataProductType     product
# 30                        Polarimetric data  DataProductType     product
# 31                            Power spectra  DataProductType     product
# 32                        Redshift catalogs  DataProductType     product
# 33                 Rotation period catalogs  DataProductType     product
# 34                        Segmentation maps  DataProductType     product
# 35             Slitless spectroscopy images  DataProductType     product
# 36                          Source catalogs  DataProductType     product
# 37           Source classification catalogs  DataProductType     product
# 38                                  Spectra  DataProductType     product
# 39                  Spectra of polarization  DataProductType     product
# 40                     Spectral image cubes  DataProductType     product
# 41                          Spectral images  DataProductType     product
# 42                     Spectral line images  DataProductType     product
# 43               Spectral line light curves  DataProductType     product
# 44                      Spectral line lists  DataProductType     product
# 45            Spectral line source catalogs  DataProductType     product
# 46                          Spectrum stacks  DataProductType     product
# 47                 Surface gravity catalogs  DataProductType     product
# 48                       Target Pixel Files  DataProductType     product
# 49                     Temperature catalogs  DataProductType     product
# 50                   Time-tagged event list  DataProductType     product
# 51                         Time domain data  DataProductType     product
# 52                              Time series  DataProductType     product
# 53                       Time series images  DataProductType     product
# 54                      Time series spectra  DataProductType     product
# 55              Turbulent velocity catalogs  DataProductType     product
# 56           Auxiliary and calibration data  DataProductType     product
# 57                     Velocity-time curves  DataProductType     product
# 58                            Velocity maps  DataProductType     product
# 59                             Visibilities  DataProductType     product
#
#     caomMatch_uri                                      ivoaMatch_uri  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# 5             NaN                                                NaN
# 6             NaN                                                NaN
# 7             NaN                                                NaN
# 8             NaN                                                NaN
# 9             NaN                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12            NaN                                                NaN
# 13            NaN                                                NaN
# 14            NaN                                                NaN
# 15            NaN                                                NaN
# 16            NaN                                                NaN
# 17            NaN                                                NaN
# 18            NaN                                                NaN
# 19            NaN  https://www.ivoa.net/rdf/product-type#light-curve
# 20            NaN                                                NaN
# 21            NaN                                                NaN
# 22            NaN                                                NaN
# 23            NaN                                                NaN
# 24            NaN                                                NaN
# 25            NaN                                                NaN
# 26            NaN          https://www.ivoa.net/rdf/product-type#sed
# 27            NaN                                                NaN
# 28            NaN                                                NaN
# 29            NaN                                                NaN
# 30            NaN  https://www.ivoa.net/rdf/product-type#polariza...
# 31            NaN                                                NaN
# 32            NaN                                                NaN
# 33            NaN                                                NaN
# 34            NaN                                                NaN
# 35            NaN                                                NaN
# 36            NaN                                                NaN
# 37            NaN                                                NaN
# 38            NaN  https://www.ivoa.net/rdf/product-type#spectral...
# 39            NaN                                                NaN
# 40            NaN                                                NaN
# 41            NaN                                                NaN
# 42            NaN                                                NaN
# 43            NaN                                                NaN
# 44            NaN                                                NaN
# 45            NaN                                                NaN
# 46            NaN                                                NaN
# 47            NaN                                                NaN
# 48            NaN                                                NaN
# 49            NaN                                                NaN
# 50            NaN                                                NaN
# 51            NaN                                                NaN
# 52            NaN                                                NaN
# 53            NaN                                                NaN
# 54            NaN  https://www.ivoa.net/rdf/product-type#dynamic-...
# 55            NaN                                                NaN
# 56            NaN                                                NaN
# 57            NaN  https://www.ivoa.net/rdf/product-type#velocity...
# 58            NaN                                                NaN
# 59            NaN   https://www.ivoa.net/rdf/product-type#visibility
#
#     uatMatch_uri
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52           NaN
# 53           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           NaN
# 58           NaN
# 59           NaN
